# %%
import pandas as pd

# Specify the path to your .tab file
file_path = 'events.2022.20230106.tab'

# Use pandas to read the .tab file
df = pd.read_csv(file_path, delimiter='\t')

# Display the DataFrame
df
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 file_path = 'events.2022.20230106.tab'
#       6 # Use pandas to read the .tab file
# ----> 7 df = pd.read_csv(file_path, delimiter='\t')
#       9 # Display the DataFrame
#      10 df
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Event ID', 'Event Date', 'Source Name', 'Source Sectors',
#        'Source Country', 'Event Text', 'CAMEO Code', 'Intensity',
#        'Target Name', 'Target Sectors', 'Target Country', 'Story ID',
#        'Sentence Number', 'Publisher', 'City', 'District', 'Province',
#        'Country', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
unique_countries = df['Source Name'].unique()


print(unique_countries)
# Out:
# ['South Korea' 'Ministry (Indonesia)' 'Denis Moncada' ... 'Audi'
#  'Political Parties (Myanmar)' 'Song Qingling']

# %%
# East Asia and US
selected_countries = ['China', 'Hong Kong', 'Macau', 'Japan', 'Mongolia', 'North Korea', 'South Korea', 'Taiwan', 'United States']

filtered_df = df[df['Source Name'].isin(selected_countries)]
filtered_df
# Out:
#         Event ID  Event Date    Source Name Source Sectors Source Country  \
# 0       36615529  2022-01-01    South Korea            NaN    South Korea
# 4       36615523  2022-01-01          China            NaN          China
# 5       36615522  2022-01-01          China            NaN          China
# 14      36615535  2022-01-01  United States            NaN  United States
# 26      36615556  2022-01-01         Taiwan            NaN         Taiwan
# ...          ...         ...            ...            ...            ...
# 796843  37530662  2022-12-31          Japan            NaN          Japan
# 796889  37530753  2022-12-31  United States            NaN  United States
# 796901  37530701  2022-12-31  United States            NaN  United States
# 796906  37533059  2022-12-31  United States            NaN  United States
# 796911  37534174  2022-12-31    South Korea            NaN    South Korea
#
#                           Event Text  CAMEO Code  Intensity  \
# ...

# %%
# Target country
filtered_df2 = filtered_df[filtered_df['Target Country'].isin(selected_countries)]
filtered_df2
# Out:
#         Event ID  Event Date    Source Name Source Sectors Source Country  \
# 0       36615529  2022-01-01    South Korea            NaN    South Korea
# 26      36615556  2022-01-01         Taiwan            NaN         Taiwan
# 67      36615614  2022-01-01          China            NaN          China
# 304     36615890  2022-01-01         Taiwan            NaN         Taiwan
# 338     36615935  2022-01-01  United States            NaN  United States
# ...          ...         ...            ...            ...            ...
# 796806  37530619  2022-12-31    North Korea            NaN    North Korea
# 796807  37530620  2022-12-31    North Korea            NaN    North Korea
# 796832  37530671  2022-12-31          China            NaN          China
# 796833  37530672  2022-12-31         Taiwan            NaN         Taiwan
# 796911  37534174  2022-12-31    South Korea            NaN    South Korea
#
#                                                Event Text  CAMEO Code  \
# ...

# %%
# change to date type
filtered_df2['Event Date'] = pd.to_datetime(filtered_df2['Event Date'])

# "Month"
filtered_df2['Month'] = filtered_df2['Event Date'].dt.month

filtered_df2
# Out:
# /var/folders/m3/k788kw6103zdvc0bwpc1lzd00000gn/T/ipykernel_34593/4170864937.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df2['Event Date'] = pd.to_datetime(filtered_df2['Event Date'])
# /var/folders/m3/k788kw6103zdvc0bwpc1lzd00000gn/T/ipykernel_34593/4170864937.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df2['Month'] = filtered_df2['Event Date'].dt.month
#         Event ID Event Date    Source Name Source Sectors Source Country  \
# ...

# %%
filtered_df2.to_csv('2022_geo_event_EA.csv', index=False)

# %%
# filter all year data
import pandas as pd

def process_event_data(file_path, output_csv_name='filtered_events.csv'):
    # Use pandas to read the .tab file
    df = pd.read_csv(file_path, delimiter='\t')

    # East Asia and US
    selected_countries = ['China', 'Hong Kong', 'Macau', 'Japan', 'Mongolia', 'North Korea', 'South Korea', 'Taiwan', 'United States']

    # Filter by source name
    filtered_df = df[df['Source Name'].isin(selected_countries)]

    # Further filter by target country
    filtered_df2 = filtered_df[filtered_df['Target Country'].isin(selected_countries)]

    # Convert to date type
    filtered_df2['Event Date'] = pd.to_datetime(filtered_df2['Event Date'])

    # Extract the month
    filtered_df2['Month'] = filtered_df2['Event Date'].dt.month

    # Save as a CSV file
    filtered_df2.to_csv(output_csv_name, index=False)

# Specify the path to your .tab file
file_path = 'events.2012.20150313084811.tab'  # Update this with your file path
output_csv_name = '2012_geo_event_EA.csv'  # Update this with your desired output file name

# Call the function
process_event_data(file_path, output_csv_name)
# Out:
# /var/folders/m3/k788kw6103zdvc0bwpc1lzd00000gn/T/ipykernel_48986/876141439.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df2['Event Date'] = pd.to_datetime(filtered_df2['Event Date'])
# /var/folders/m3/k788kw6103zdvc0bwpc1lzd00000gn/T/ipykernel_48986/876141439.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df2['Month'] = filtered_df2['Event Date'].dt.month

# %%
# merge data

import pandas as pd
from glob import glob

# Specify the pattern for matching the CSV files
file_pattern = '20*_geo_event_EA.csv'

# Use glob to get a list of file names matching the pattern
file_names = glob(file_pattern)

# Create an empty list to store DataFrames
dfs = []

# Loop through each file, read it as a DataFrame, and append to the list
for file in file_names:
    year = int(file[:4])  # Extract the year from the file name
    df = pd.read_csv(file)
    df['Year'] = year  # Add a 'Year' column
    dfs.append(df)

# Concatenate the list of DataFrames into a single DataFrame
merged_geo_event_data = pd.concat(dfs, ignore_index=True)

# Display the merged DataFrame
print(merged_geo_event_data.head())

# Save the merged DataFrame to a new CSV file if needed
merged_geo_event_data.to_csv('merged_geo_event_data.csv', index=False)
# Out:
#    Event ID  Event Date  Source Name  Source Sectors Source Country  \
# 0  33417401  2018-01-01  South Korea             NaN    South Korea
# 1  33417584  2018-01-01  North Korea             NaN    North Korea
# 2  33417316  2018-01-01  North Korea             NaN    North Korea
# 3  33417511  2018-01-01  South Korea             NaN    South Korea
# 4  33417390  2018-01-01  North Korea             NaN    North Korea
#
#                         Event Text CAMEO Code  Intensity  \
# 0                Praise or endorse         51        3.4
# 1  Use conventional military force        190      -10.0
# 2  Use conventional military force        190      -10.0
# 3                Praise or endorse         51        3.4
# 4                         Threaten        130       -4.4
#
#                Target Name                                     Target Sectors  \
# 0              Kim Jong-Un  (National) Major Party,Parties,Government Majo...
# ...
