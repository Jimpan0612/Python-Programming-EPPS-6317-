# %% [markdown]
# ## Jupyter tutorial: Open Source GIS in Python
#
# Jim, GISC 6317
#
# Last updated: 11/05/2023
#
# Purpose: Jupyter tutorial that includes how to intall 'GDAL', and learn how to use 'fiona' and 'rasterio'.

# %% [markdown]
# ## Opening a shapefile in Fiona

# %%
import fiona

# %%
miairports = fiona.open("/Users/jimpan/Documents/EPPS 6317/Labs/lab9/mi_airports_shp/mi_airports.shp")
miairports
# Out:
# <open Collection '/Users/jimpan/Documents/EPPS 6317/Labs/lab9/mi_airports_shp/mi_airports.shp:mi_airports', mode 'r' at 0x122edeab0>

# %%
# Get first feature
f = miairports.next()
# What geometry type is it?
f['geometry']['type']
# Out:
# /var/folders/m3/k788kw6103zdvc0bwpc1lzd00000gn/T/ipykernel_69859/1394809352.py:2: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   f = miairports.next()
# 'Point'

# %%
# Count features
num_features = len(miairports)
num_features
# Out:
# 539

# %%
# Get the shapefile extent
miairports.bounds
# Out:
# (183056.125, 132988.953125, 788825.6875, 738138.0625)

# %%
miairports.schema
# Out:
# {'properties': {'ID': 'int:11',
#   'NAME': 'str:63',
#   'TYPE': 'str:9',
#   'COUNTY': 'str:14',
#   'FIPS': 'int:11',
#   'Y_COR': 'int:11',
#   'X_COR': 'int:11',
#   'ELEVATION': 'int:11',
#   'LOCATION': 'str:29'},
#  'geometry': 'Point'}

# %%
# Use shapefile properties in conditional logic
if miairports.schema['geometry'] == 'Point':
    print("This is a point file")
elif miairports.schema['geometry'] == 'LineString' or miairports.schema['geometry'] == 'MultiLineString':
    print("This is a line file")
elif miairports.schema['geometry'] == 'Polygon' or miairports.schema['geometry'] == 'MultiPolygon':
    print("This is a polygon file")
else:
    print("I don't know *what* this is!")
# Out:
# This is a point file

# %%
# Identify the number of airports in Ingham county

# List comprehension to filter airports in Ingham county
airports_in_ingham = []

for airport in miairports:
    # Iterate through each 'airport' feature in the miairports dataset
    if airport['properties']['COUNTY'] == 'Ingham':
        # Check if the 'COUNTY' property of the current airport is 'Ingham'
        airports_in_ingham.append(airport)
        # If 'COUNTY' is 'Ingham', add the airport to the 'airports_in_ingham' list

# The 'airports_in_ingham' list will contain all airports in 'Ingham' county

num_airports_in_ingham = len(airports_in_ingham)
num_airports_in_ingham
# Out:
# 10

# %%
# Find the airport with the highest elevation
elevation_sorted = sorted(miairports, key=lambda x: x['properties']['ELEVATION'], reverse=True)
elevation_sorted

# Loop through sorted airports by elevation in descending order
for airport in elevation_sorted:
    airport_name = airport['properties']['NAME']
    airport_elevation = airport['properties']['ELEVATION']
    print(f"The airport '{airport_name}' has an elevation of {airport_elevation} feet.")
# Out:
# The airport 'Marenisco Landing Field' has an elevation of 1638 feet.
# The airport 'Northwoods Center Conference Airport' has an elevation of 1633 feet.
# The airport 'NRC Airport' has an elevation of 1625 feet.
# The airport 'Stambaugh Airport' has an elevation of 1622 feet.
# The airport 'Hide-Away Village Landing Strip' has an elevation of 1525 feet.
# The airport 'Edward F Johnson Airport' has an elevation of 1446 feet.
# The airport 'Marquette County Airport' has an elevation of 1419 feet.
# The airport 'Huber Airport' has an elevation of 1418 feet.
# The airport 'Prickett-Grooms Field' has an elevation of 1372 feet.
# The airport 'Prickett Grooms Airport' has an elevation of 1361 feet.
# The airport 'Iron County Airport' has an elevation of 1340 feet.
# The airport 'Otsego County Airport' has an elevation of 1328 feet.
# The airport 'McQuestions Airport' has an elevation of 1317 feet.
# The airport 'Wexford County Airport' has an elevation of 1309 feet.
# The airport 'Wexford County Airport' has an elevation of 1307 feet.
# The airport 'Great Lakes Airport' has an elevation of 1300 feet.
# The airport 'Lake of the North Airport' has an elevation of 1286 feet.
# The airport 'Twin Lakes Airport' has an elevation of 1275 feet.
# The airport 'Lilienthal Airport' has an elevation of 1250 feet.
# The airport 'Home Acres Sky Ranch' has an elevation of 1247 feet.
# The airport 'Gogebic County Airport' has an elevation of 1230 feet.
# The airport 'K I Sawyer Air Force Base' has an elevation of 1220 feet.
# The airport 'Garland Airport' has an elevation of 1218 feet.
# The airport 'Moorestown Airpark' has an elevation of 1213 feet.
# The airport 'Higgins Lake Airport' has an elevation of 1205 feet.
# The airport 'Saint Helen Airport' has an elevation of 1198 feet.
# The airport 'Hillsdale Municipal Airport' has an elevation of 1182 feet.
# The airport 'Ford Airport' has an elevation of 1182 feet.
# The airport 'Air Park North' has an elevation of 1173 feet.
# The airport 'Simar Landing Strip' has an elevation of 1171 feet.
# The airport 'Houghton Lake State Airport' has an elevation of 1165 feet.
# The airport 'Grayling Army Air Field Airport' has an elevation of 1158 feet.
# The airport 'Roscommon Conservation Airport' has an elevation of 1156 feet.
# The airport 'Woodworth Landing Field' has an elevation of 1152 feet.
# The airport 'Roscommon County Airport' has an elevation of 1150 feet.
# The airport 'Handleman Sky Ranch' has an elevation of 1150 feet.
# The airport 'Clare County Airport' has an elevation of 1142 feet.
# The airport 'Hillsdale Hospital Heliport' has an elevation of 1141 feet.
# The airport 'Mancelona Municipal Airport' has an elevation of 1133 feet.
# The airport 'Lesterson Field' has an elevation of 1120 feet.
# The airport 'Fontecchio Airport' has an elevation of 1110 feet.
# The airport 'King Trout Airport' has an elevation of 1100 feet.
# The airport 'Nikkila Farms Airport' has an elevation of 1100 feet.
# The airport 'Houghton County Memorial Airport' has an elevation of 1095 feet.
# The airport 'Rocky Pine Airport' has an elevation of 1085 feet.
# The airport 'Hougton County Memorial Airport' has an elevation of 1068 feet.
# The airport 'Scott Airstrip' has an elevation of 1065 feet.
# The airport 'Nartron Field' has an elevation of 1055 feet.
# The airport 'Lost Creek Airport' has an elevation of 1051 feet.
# The airport 'Oscoda County Airport' has an elevation of 1050 feet.
# The airport 'Doss Field' has an elevation of 1050 feet.
# The airport 'Ed Schultes Place Stolport' has an elevation of 1050 feet.
# The airport 'Willie Run Airport' has an elevation of 1043 feet.
# The airport 'Highland Heliport' has an elevation of 1040 feet.
# The airport 'Kalkaska City Airport' has an elevation of 1030 feet.
# The airport 'Ponderosa Heliport' has an elevation of 1030 feet.
# The airport 'Mecosta Morton Airport' has an elevation of 1022 feet.
# The airport 'Evart Municipal Airport' has an elevation of 1018 feet.
# The airport 'Capen Airport' has an elevation of 1015 feet.
# The airport 'Circle T Ranch Airport' has an elevation of 1010 feet.
# The airport 'Bunchs Half Acre Airport' has an elevation of 1010 feet.
# The airport 'Rossettie Airport' has an elevation of 1005 feet.
# The airport 'Jackson County-Reynolds Field' has an elevation of 1001 feet.
# The airport 'Kelleys Airport' has an elevation of 1000 feet.
# The airport 'Haigh Airport' has an elevation of 1000 feet.
# The airport 'Winters Field' has an elevation of 1000 feet.
# The airport 'Shamrock Field' has an elevation of 995 feet.
# The airport 'Roben-Hood Airport' has an elevation of 990 feet.
# The airport 'Trollmans Field' has an elevation of 990 feet.
# The airport 'Loars Field Incorporated Airport' has an elevation of 990 feet.
# The airport 'Claucherty Airport' has an elevation of 988 feet.
# The airport 'Hanley Field' has an elevation of 984 feet.
# The airport 'Hanley Landing Strip' has an elevation of 983 feet.
# The airport 'Oakland-Pontiac Airport' has an elevation of 980 feet.
# The airport 'Riske Airport' has an elevation of 980 feet.
# The airport 'Day Field' has an elevation of 980 feet.
# The airport 'Hynes Field' has an elevation of 978 feet.
# The airport 'Dvoracek Field' has an elevation of 975 feet.
# The airport 'Brighton Airport' has an elevation of 973 feet.
# The airport 'Lakeview Airport-Griffith Field' has an elevation of 971 feet.
# The airport 'Wagners Landing Heliport' has an elevation of 970 feet.
# The airport 'Adams Heliport' has an elevation of 970 feet.
# The airport 'McPhail Heliport' has an elevation of 970 feet.
# The airport 'Nitz Heliport' has an elevation of 970 feet.
# The airport 'Bonnie Field' has an elevation of 970 feet.
# The airport 'W A Foote Memorial Hospital Heliport' has an elevation of 965 feet.
# The airport 'Williams Airport' has an elevation of 963 feet.
# The airport 'Midway Airport' has an elevation of 963 feet.
# The airport 'Napoleon Airport' has an elevation of 963 feet.
# The airport 'Livingston County Airport' has an elevation of 961 feet.
# The airport 'Canadian Lakes Airport' has an elevation of 960 feet.
# The airport 'Charles Airport' has an elevation of 960 feet.
# The airport 'Williams Field' has an elevation of 960 feet.
# The airport 'Community Health Center of Branch County Heliport' has an elevation of 959 feet.
# The airport 'Branch County Memorial Airport' has an elevation of 959 feet.
# The airport 'W K Kellogg Airport' has an elevation of 952 feet.
# The airport 'Ojibwa Airpark' has an elevation of 950 feet.
# The airport 'Timbers Sky Camp Airport' has an elevation of 945 feet.
# The airport 'Empire Airport' has an elevation of 944 feet.
# The airport 'A C Miller Airport' has an elevation of 944 feet.
# The airport 'Brooks Field' has an elevation of 941 feet.
# The airport 'Sugar Springs Airport' has an elevation of 940 feet.
# The airport 'Woodruff Lake Airport' has an elevation of 940 feet.
# The airport 'T and M Companies Heliport' has an elevation of 938 feet.
# The airport 'Spencer Field' has an elevation of 936 feet.
# The airport 'Junior North Heliport' has an elevation of 935 feet.
# The airport 'Kamikaze Run Heliport' has an elevation of 935 feet.
# The airport 'Skyway Estates Airport' has an elevation of 931 feet.
# The airport 'L D Ranch Airport' has an elevation of 930 feet.
# The airport 'Thorn Hospital Heliport' has an elevation of 930 feet.
# The airport 'Roben-Hood Airport' has an elevation of 929 feet.
# The airport 'Pontiac Stadium Heliport' has an elevation of 926 feet.
# The airport 'New Hudson Airport' has an elevation of 926 feet.
# The airport 'Kirsch Municipal Airport' has an elevation of 925 feet.
# The airport 'Richmond Field' has an elevation of 921 feet.
# The airport 'Prices Airport' has an elevation of 920 feet.
# The airport 'Maidens Airport' has an elevation of 920 feet.
# The airport 'Law Field' has an elevation of 920 feet.
# The airport 'Glen Oaks Heliport' has an elevation of 920 feet.
# The airport 'Heliflite Heliport' has an elevation of 920 feet.
# The airport 'Carriage Lane Airport' has an elevation of 920 feet.
# The airport 'Gooding Airport' has an elevation of 920 feet.
# The airport 'Mason Jewett Field' has an elevation of 919 feet.
# The airport 'Raco Field' has an elevation of 918 feet.
# The airport 'Whitcomb Field' has an elevation of 915 feet.
# The airport 'White Cloud Airport' has an elevation of 914 feet.
# The airport 'White Cloud Airport' has an elevation of 912 feet.
# The airport 'Oceana County Airport' has an elevation of 910 feet.
# The airport 'Palmer Field' has an elevation of 910 feet.
# The airport 'Maple Grove Airport' has an elevation of 908 feet.
# The airport 'North Kent Airpark' has an elevation of 905 feet.
# The airport 'Anderson Airport' has an elevation of 902 feet.
# The airport 'Lakeside Airport' has an elevation of 900 feet.
# The airport 'Eichmeier Field' has an elevation of 900 feet.
# The airport 'Bergeon Field' has an elevation of 900 feet.
# The airport 'Dysinger Airport' has an elevation of 897 feet.
# The airport 'Marlette Airport' has an elevation of 895 feet.
# The airport 'Oceana County Airport' has an elevation of 894 feet.
# The airport 'Perry Airport' has an elevation of 894 feet.
# The airport 'North Cedar Airport' has an elevation of 893 feet.
# The airport 'Wabasis Lake Airport' has an elevation of 892 feet.
# The airport 'Survival Flight Heliport' has an elevation of 892 feet.
# The airport 'Fitch H Beach Airport' has an elevation of 891 feet.
# The airport 'Witbeck Aerodrone Airport' has an elevation of 890 feet.
# The airport 'Wells Airport' has an elevation of 890 feet.
# The airport 'Crippen Field' has an elevation of 890 feet.
# The airport 'Cackleberry Airport' has an elevation of 890 feet.
# The airport 'Larry D Boven Airport' has an elevation of 890 feet.
# The airport 'Cain Field' has an elevation of 889 feet.
# The airport 'Davids Airport' has an elevation of 887 feet.
# The airport 'Lake Isabella Airpark' has an elevation of 886 feet.
# The airport 'Boyer Airport' has an elevation of 883 feet.
# The airport 'Custer Main Heliport' has an elevation of 883 feet.
# The airport 'West Branch Community Airport' has an elevation of 882 feet.
# The airport 'Black River Ranch Airport' has an elevation of 880 feet.
# The airport 'Rapids Airway Airport' has an elevation of 880 feet.
# The airport 'Ramsy Farm Airport' has an elevation of 880 feet.
# The airport 'Atlanta Municipal Airport' has an elevation of 875 feet.
# The airport 'Kalamazoo-Battle Creek International Airport' has an elevation of 874 feet.
# The airport 'Stan Nowiki Airport' has an elevation of 872 feet.
# The airport 'Almont Airport' has an elevation of 871 feet.
# The airport 'Austin Lake Airport' has an elevation of 871 feet.
# The airport 'Cridler Airport' has an elevation of 870 feet.
# The airport 'Luce County Hale Airport' has an elevation of 869 feet.
# The airport 'Green Lake Airport' has an elevation of 866 feet.
# The airport 'Omans Heliport' has an elevation of 865 feet.
# The airport 'Capital City Airport' has an elevation of 861 feet.
# The airport 'Howe Airport' has an elevation of 860 feet.
# The airport 'Edward W Sparrow Hospital Heliport' has an elevation of 860 feet.
# The airport 'State Police Headquarters Heliport' has an elevation of 860 feet.
# The airport 'Ingham Medical Helistop' has an elevation of 860 feet.
# The airport 'East Lake Airport' has an elevation of 860 feet.
# The airport 'Wend Valley Airport' has an elevation of 859 feet.
# The airport 'Chatham Landing Strip' has an elevation of 858 feet.
# The airport 'Thompson Airport' has an elevation of 857 feet.
# The airport 'University Airpark' has an elevation of 856 feet.
# The airport 'Greenville Municipal Airport' has an elevation of 855 feet.
# The airport 'Leila Hospital Helistop' has an elevation of 855 feet.
# The airport 'Hiram Cure Airport' has an elevation of 853 feet.
# The airport 'Airbatco Field' has an elevation of 852 feet.
# The airport 'Hillman Airport' has an elevation of 850 feet.
# The airport 'Stier Airstrip' has an elevation of 850 feet.
# The airport 'Cupp/SJVS Landing Strip' has an elevation of 850 feet.
# The airport 'Independence Green Heliport' has an elevation of 850 feet.
# The airport 'Thrall Lake Airport' has an elevation of 850 feet.
# The airport 'Baldwin Lake Heliport' has an elevation of 850 feet.
# The airport 'Stony Acres Airport' has an elevation of 849 feet.
# The airport 'Borgess Medical Center Heliport' has an elevation of 849 feet.
# The airport 'Davis Airport' has an elevation of 845 feet.
# The airport 'Dupont-Lapeer Airport' has an elevation of 844 feet.
# The airport 'Abrams Municipal Airport' has an elevation of 842 feet.
# The airport 'Michigan National Guard Headquarters Heliport' has an elevation of 842 feet.
# The airport 'Vacottage Heliport' has an elevation of 840 feet.
# The airport 'Newmans Airport' has an elevation of 840 feet.
# The airport 'Ann Arbor Municipal Airport' has an elevation of 839 feet.
# The airport 'Grand Marais Airport' has an elevation of 838 feet.
# The airport 'CMHS Heliport' has an elevation of 837 feet.
# The airport 'Guardian Industries Heliport' has an elevation of 832 feet.
# The airport 'Clare Municipal Airport' has an elevation of 831 feet.
# The airport 'Leo E Goetz County Airport' has an elevation of 830 feet.
# The airport 'Flying M Ranch Airport' has an elevation of 830 feet.
# The airport 'Cole Field' has an elevation of 830 feet.
# The airport 'Mattawan Airpark' has an elevation of 830 feet.
# The airport 'Stueben Landing Field' has an elevation of 829 feet.
# The airport 'Baldwin Municipal Airport' has an elevation of 828 feet.
# The airport 'Dennis Farms Airport' has an elevation of 826 feet.
# The airport 'Sugar Loaf Resort Airport' has an elevation of 825 feet.
# The airport 'Betsie River Airstrip' has an elevation of 825 feet.
# The airport 'Hamp Airport' has an elevation of 825 feet.
# The airport 'Markham Airport' has an elevation of 825 feet.
# The airport 'Three Rivers Municipal/Doctor Haines Airport' has an elevation of 824 feet.
# The airport 'Bixby Hospital Heliport' has an elevation of 821 feet.
# The airport 'Johns Airport' has an elevation of 820 feet.
# The airport 'Barnstormers 5 Airport' has an elevation of 820 feet.
# The airport 'Honey Acres Airport' has an elevation of 820 feet.
# The airport 'Merillat Airport' has an elevation of 820 feet.
# The airport 'Wisner Airport' has an elevation of 819 feet.
# The airport 'Grant Airport' has an elevation of 815 feet.
# The airport 'Al Meyers Airport' has an elevation of 815 feet.
# The airport 'Yale Airport' has an elevation of 814 feet.
# The airport 'Ionia County Airport' has an elevation of 813 feet.
# The airport 'Tyrone Airport' has an elevation of 810 feet.
# The airport 'Lee Field' has an elevation of 810 feet.
# The airport 'Johnson Airport' has an elevation of 810 feet.
# The airport 'Shafter Airport' has an elevation of 805 feet.
# The airport 'Bass Lake Airport' has an elevation of 805 feet.
# The airport 'UMMC Heliport' has an elevation of 802 feet.
# The airport 'Hastings Airport' has an elevation of 801 feet.
# The airport 'Para Field' has an elevation of 800 feet.
# The airport 'Gavagan Field' has an elevation of 800 feet.
# The airport 'Blodgett Memorial Medical Center Heliport' has an elevation of 800 feet.
# The airport 'Hoerners Corners Airport' has an elevation of 800 feet.
# The airport 'Carls Airport' has an elevation of 800 feet.
# The airport 'Rentz Ultralight Airport' has an elevation of 800 feet.
# The airport 'Youngs Airport' has an elevation of 800 feet.
# The airport 'Turtle Lake Club Airport' has an elevation of 799 feet.
# The airport 'Chippewa County International Airport' has an elevation of 799 feet.
# The airport 'Lenawee County Airport' has an elevation of 798 feet.
# The airport 'Archer Field' has an elevation of 794 feet.
# The airport 'Kent County International Airport' has an elevation of 794 feet.
# The airport 'Thompsonville Airport' has an elevation of 793 feet.
# The airport 'Tecumseh Products Airport' has an elevation of 791 feet.
# The airport 'Mayes Airport' has an elevation of 790 feet.
# The airport 'GRH Heliport' has an elevation of 790 feet.
# The airport 'Bronson Methodist Hospital Heliport' has an elevation of 786 feet.
# The airport 'Vlachos Acres Airport' has an elevation of 785 feet.
# The airport 'Triple H Airport' has an elevation of 785 feet.
# The airport 'Horaks Airport' has an elevation of 784 feet.
# The airport 'Bishop International Airport' has an elevation of 782 feet.
# The airport 'Arnold Field' has an elevation of 780 feet.
# The airport 'Grass Roots Stolport' has an elevation of 780 feet.
# The airport 'Athelone Williams Memorial Airport' has an elevation of 780 feet.
# The airport 'Kidder Field Heliport' has an elevation of 780 feet.
# The airport 'Overflow Pad' has an elevation of 780 feet.
# The airport 'Kerby Field' has an elevation of 780 feet.
# The airport 'Arnold Lunding Field' has an elevation of 779 feet.
# The airport 'Charles C Zettel Memorial Airport' has an elevation of 776 feet.
# The airport 'Sandusky City Airport' has an elevation of 776 feet.
# The airport 'Innes Acres Airport' has an elevation of 775 feet.
# The airport 'Glowacki Airport' has an elevation of 775 feet.
# The airport 'Newaygo Airport' has an elevation of 774 feet.
# The airport 'Newaygo Airport' has an elevation of 774 feet.
# The airport 'Duford Field' has an elevation of 773 feet.
# The airport 'Silver Lake Airport' has an elevation of 772 feet.
# The airport 'Fremont Municipal Airport' has an elevation of 772 feet.
# The airport 'Williams Field' has an elevation of 772 feet.
# The airport 'Cowley Field' has an elevation of 770 feet.
# The airport 'Peck Air Park' has an elevation of 770 feet.
# The airport 'Tackaberry Airport' has an elevation of 770 feet.
# The airport 'McPhail Corporation Heliport' has an elevation of 770 feet.
# The airport 'Kriewall Strip' has an elevation of 765 feet.
# The airport 'Huron County Memorial Airport' has an elevation of 763 feet.
# The airport 'Sparta Airport' has an elevation of 761 feet.
# The airport 'Hancock Airport' has an elevation of 760 feet.
# The airport 'Albert J Lindberg Airport' has an elevation of 760 feet.
# The airport 'Boyne Highlands Landing Strip' has an elevation of 757 feet.
# The airport 'Boyne Highlands Airport' has an elevation of 757 feet.
# The airport 'Hessel Landing Field' has an elevation of 757 feet.
# The airport 'D J Airport' has an elevation of 755 feet.
# The airport 'Mount Pleasant Municipal Airport' has an elevation of 755 feet.
# The airport 'Jensen Field' has an elevation of 755 feet.
# The airport 'B and G Heliport' has an elevation of 755 feet.
# The airport 'Gratiot Community Airport' has an elevation of 754 feet.
# The airport 'Schenkel Field' has an elevation of 750 feet.
# The airport 'East-West Paris Airport' has an elevation of 750 feet.
# The airport 'Walker Airport' has an elevation of 750 feet.
# The airport 'Wolvertons Field' has an elevation of 750 feet.
# The airport 'Jerry Tyler Memorial Airport' has an elevation of 750 feet.
# The airport 'OConner County Airstrip' has an elevation of 749 feet.
# The airport 'Dowagiac Municipal Airport' has an elevation of 748 feet.
# The airport 'Lee Memorial Hospital Heliport' has an elevation of 748 feet.
# The airport 'Butterworth Hospital Heliport' has an elevation of 746 feet.
# The airport 'Indian Creek Ranch Airport' has an elevation of 745 feet.
# The airport 'Romeo Airport' has an elevation of 745 feet.
# The airport 'Crump Airport' has an elevation of 745 feet.
# The airport 'Wayland Municipal Airport' has an elevation of 740 feet.
# The airport 'Beckman Airport' has an elevation of 740 feet.
# The airport 'Almena Airport' has an elevation of 740 feet.
# The airport 'Mackinac Island Airport' has an elevation of 740 feet.
# The airport 'Flow Through Terminal Heliport' has an elevation of 736 feet.
# The airport 'Owosso Community Airport' has an elevation of 736 feet.
# The airport 'Fasel Field' has an elevation of 735 feet.
# The airport 'Schiffer Acres Airport' has an elevation of 735 feet.
# The airport 'Daltons Airport' has an elevation of 733 feet.
# The airport 'MacKinac Island Airport' has an elevation of 731 feet.
# The airport 'Wilson Township Airport' has an elevation of 730 feet.
# The airport 'McJilton Field' has an elevation of 729 feet.
# The airport 'Oakland-Troy Airport' has an elevation of 729 feet.
# The airport 'MacKinaw City Municipal Airport' has an elevation of 727 feet.
# The airport 'Rasor Airport' has an elevation of 726 feet.
# The airport 'Flying T Ranch Airport' has an elevation of 725 feet.
# The airport 'Wightman Airport' has an elevation of 725 feet.
# The airport 'Cedarville Airport' has an elevation of 725 feet.
# The airport 'Cagney Airport' has an elevation of 722 feet.
# The airport 'Otsego-Plainwell Municipal Airport' has an elevation of 722 feet.
# The airport 'West Gladstone Airport' has an elevation of 722 feet.
# The airport 'Sault Sainte Marie Municipal Airport' has an elevation of 721 feet.
# The airport 'Pellston Regional Airport of Emmet County' has an elevation of 720 feet.
# The airport 'Minarik Airport' has an elevation of 720 feet.
# The airport 'W Gladstone Airport' has an elevation of 720 feet.
# The airport 'Boyne Mountain Airport' has an elevation of 719 feet.
# The airport 'Tripp Creek Airport' has an elevation of 717 feet.
# The airport 'Willow Run Airport' has an elevation of 716 feet.
# The airport 'ATI Heliport' has an elevation of 716 feet.
# The airport 'Sault Sainte Marie Municipal/Sanderson Field' has an elevation of 716 feet.
# The airport 'Bendix Heliport' has an elevation of 715 feet.
# The airport 'Ringer Landing Strip' has an elevation of 714 feet.
# The airport 'Acme Skyport' has an elevation of 711 feet.
# The airport 'William Beaumont Hospital Heliport' has an elevation of 710 feet.
# The airport 'Brevort Airport' has an elevation of 710 feet.
# The airport 'Acme Airport' has an elevation of 708 feet.
# The airport 'J P's Field' has an elevation of 708 feet.
# The airport 'Padgham Field' has an elevation of 708 feet.
# The airport 'Milan Airport' has an elevation of 706 feet.
# The airport 'Miller Field' has an elevation of 705 feet.
# The airport 'Dodge Airport' has an elevation of 705 feet.
# The airport 'Dowd Field' has an elevation of 705 feet.
# The airport 'Dowd Landing Strip' has an elevation of 701 feet.
# The airport 'Caro Municipal Airport' has an elevation of 700 feet.
# The airport 'Streams Airpark' has an elevation of 700 feet.
# The airport 'Randolphs Landing Area' has an elevation of 700 feet.
# The airport 'Reading Airport' has an elevation of 700 feet.
# The airport 'Harrisville Municipal Airport' has an elevation of 698 feet.
# The airport 'Mettetal-Canton Airport' has an elevation of 696 feet.
# The airport 'Larsen Air Park' has an elevation of 696 feet.
# The airport 'Brablec Farms Airport' has an elevation of 691 feet.
# The airport 'Betz Airport' has an elevation of 691 feet.
# The airport 'Pbeaaye Airport' has an elevation of 690 feet.
# The airport 'Ludington Airport' has an elevation of 690 feet.
# The airport 'Executive Heliport' has an elevation of 690 feet.
# The airport 'Alpena County Regional Airport' has an elevation of 689 feet.
# The airport 'Tulip City Airport' has an elevation of 689 feet.
# The airport 'Schuster Field' has an elevation of 688 feet.
# The airport 'Harbor Springs Airport' has an elevation of 686 feet.
# The airport 'Stickel Landing Strip' has an elevation of 686 feet.
# The airport 'Phils Field' has an elevation of 685 feet.
# The airport 'Schoolcraft County Airport' has an elevation of 685 feet.
# The airport 'Harbor Springs Airport' has an elevation of 684 feet.
# The airport 'Schoolcraft County Airport' has an elevation of 684 feet.
# The airport 'Ottiger Airport' has an elevation of 683 feet.
# The airport 'Downwind Acres Airport' has an elevation of 683 feet.
# The airport 'Lowell City Airport' has an elevation of 681 feet.
# The airport 'Cromptons Strip' has an elevation of 680 feet.
# The airport 'Bakers Field' has an elevation of 680 feet.
# The airport 'Ham-A-Lot Field' has an elevation of 680 feet.
# The airport 'Air Rahe Airport' has an elevation of 680 feet.
# The airport 'Zeitler Airport' has an elevation of 678 feet.
# The airport 'Lada Airport' has an elevation of 678 feet.
# The airport 'TV2 Heliport' has an elevation of 677 feet.
# The airport 'Harrisville Airport' has an elevation of 675 feet.
# The airport 'Tanke Field' has an elevation of 675 feet.
# The airport 'BPS Heliport' has an elevation of 675 feet.
# The airport 'Laszlo Airport' has an elevation of 675 feet.
# The airport 'Rosedale Airport' has an elevation of 675 feet.
# The airport 'Gradolph Field' has an elevation of 673 feet.
# The airport 'Presque Isle County Airport' has an elevation of 672 feet.
# The airport 'Bridgman Community Air Park' has an elevation of 671 feet.
# The airport 'Presque Isle County Airport' has an elevation of 670 feet.
# The airport 'Charlevoix Municipal Airport' has an elevation of 670 feet.
# The airport 'Amway Downtown Heliport' has an elevation of 670 feet.
# The airport 'WDIV-TV Channel 4 Heliport' has an elevation of 670 feet.
# The airport 'Myers Airport' has an elevation of 670 feet.
# The airport 'Beaver Island Airport' has an elevation of 669 feet.
# The airport 'Midget Airport' has an elevation of 669 feet.
# The airport 'Toledo Suburban Airport' has an elevation of 669 feet.
# The airport 'Ontonagon County Airport' has an elevation of 669 feet.
# The airport 'Beaver Island Airport' has an elevation of 668 feet.
# The airport 'Tri City International Airport' has an elevation of 668 feet.
# The airport 'Drummond Island Airport' has an elevation of 668 feet.
# The airport 'Coopersville Airport' has an elevation of 666 feet.
# The airport 'Jim Morgan Field' has an elevation of 665 feet.
# The airport 'Andrews University Airpark' has an elevation of 665 feet.
# The airport 'Nelson Airport' has an elevation of 665 feet.
# The airport 'Oselka Airport' has an elevation of 665 feet.
# The airport 'Welke Airport' has an elevation of 664 feet.
# The airport 'Welke Airport' has an elevation of 664 feet.
# The airport 'South Haven Area Regional Airport' has an elevation of 663 feet.
# The airport 'Harrys Field' has an elevation of 662 feet.
# The airport 'Pear Grove Airport' has an elevation of 660 feet.
# The airport 'Pewanogowink-Banks Airport' has an elevation of 660 feet.
# The airport 'Saint Marys Hospital Heliport' has an elevation of 660 feet.
# The airport 'Somerville Airport' has an elevation of 660 feet.
# The airport 'South Haven Municipal Airport' has an elevation of 660 feet.
# The airport 'Southfork Airport' has an elevation of 660 feet.
# The airport 'Demler Landing Strip' has an elevation of 658 feet.
# The airport 'Boyne City Municipal Airport' has an elevation of 657 feet.
# The airport 'Sumner Heliport' has an elevation of 657 feet.
# The airport 'Watervliet Municipal Airport' has an elevation of 656 feet.
# The airport 'Ontonagon County Airport' has an elevation of 655 feet.
# The airport 'Bois Blanc Airport' has an elevation of 653 feet.
# The airport 'Northside Airport' has an elevation of 652 feet.
# The airport 'Big Beaver Airport' has an elevation of 652 feet.
# The airport 'Saint Clair County International Airport' has an elevation of 650 feet.
# The airport 'Saint Clair County International Airport' has an elevation of 650 feet.
# The airport 'Cobo Hall Heliport' has an elevation of 650 feet.
# The airport 'Yuba Airport' has an elevation of 645 feet.
# The airport 'Mason County Airport' has an elevation of 645 feet.
# The airport 'William 'Tiny' Zehnder Field' has an elevation of 645 feet.
# The airport 'Acme Heliport' has an elevation of 645 feet.
# The airport 'Del Hickcox Airport' has an elevation of 645 feet.
# The airport 'Drummond Island Airport' has an elevation of 645 feet.
# The airport 'Howard Nixon Memorial Airport' has an elevation of 644 feet.
# The airport 'Charlevoix Municipal Airport' has an elevation of 643 feet.
# The airport 'Mason County Airport' has an elevation of 643 feet.
# The airport 'Ross Field-Twin Cities Airport' has an elevation of 643 feet.
# The airport 'East Jordan City Airport' has an elevation of 642 feet.
# The airport 'Torchport Airport' has an elevation of 640 feet.
# The airport 'Trowbridge Farms Airport' has an elevation of 640 feet.
# The airport 'Detroit Metropolitan Wayne County Airport' has an elevation of 640 feet.
# The airport 'Cheboygan City-County Airport' has an elevation of 639 feet.
# The airport 'Torchport Landing Strip' has an elevation of 638 feet.
# The airport 'Grant Pad Heliport' has an elevation of 638 feet.
# The airport 'North Michigan Hospitals Incorporated Heliport' has an elevation of 636 feet.
# The airport 'Dow Division Heliport' has an elevation of 635 feet.
# The airport 'Muskegon General Hospital Heliport' has an elevation of 635 feet.
# The airport 'Walle Field' has an elevation of 635 feet.
# The airport 'Oscoda-Wurtsmith Airport' has an elevation of 634 feet.
# The airport 'Jack Barstow Airport' has an elevation of 634 feet.
# The airport 'Jablonski Airport' has an elevation of 634 feet.
# The airport 'Johnson Landing Strip' has an elevation of 633 feet.
# The airport 'Henry Ford Hospital Heliport' has an elevation of 633 feet.
# The airport 'Macomb Airport' has an elevation of 632 feet.
# The airport 'Adair Airstrip' has an elevation of 631 feet.
# The airport 'Doyle Township Emergency Landing Field' has an elevation of 631 feet.
# The airport 'Standish Industrial Airport' has an elevation of 630 feet.
# The airport 'Flying-A-Ranch Airport' has an elevation of 630 feet.
# The airport 'Johnson Field' has an elevation of 630 feet.
# The airport 'Curts Place Airport' has an elevation of 630 feet.
# The airport 'Jott Heliport' has an elevation of 630 feet.
# The airport 'Detroit Medical Center Heliport' has an elevation of 630 feet.
# The airport 'Franklins Airport' has an elevation of 630 feet.
# The airport 'Munson Medical Center Heliport' has an elevation of 629 feet.
# The airport 'Frankfort City - Benzie County Airport' has an elevation of 629 feet.
# The airport 'Standish City Airport' has an elevation of 629 feet.
# The airport 'Woolsey Memorial Airport' has an elevation of 628 feet.
# The airport 'City-County Airport' has an elevation of 628 feet.
# The airport 'Hackley Hospital Emergency Heliport' has an elevation of 628 feet.
# The airport 'Muskegon County Airport' has an elevation of 628 feet.
# The airport 'Detroit City Airport' has an elevation of 626 feet.
# The airport 'Menominee-Marinette Twin County Airport' has an elevation of 625 feet.
# The airport 'Miller-Herrold Airport' has an elevation of 624 feet.
# The airport 'Cherry Capital Airport' has an elevation of 624 feet.
# The airport 'Van Strien Company Airport' has an elevation of 624 feet.
# The airport 'Antrim County Airport' has an elevation of 623 feet.
# The airport 'MacKinac County Airport' has an elevation of 623 feet.
# The airport 'Mackinac County Airport' has an elevation of 623 feet.
# The airport 'Franklin Landing Strip' has an elevation of 621 feet.
# The airport 'Manistee - Blacker Airport' has an elevation of 620 feet.
# The airport 'Manistee County-Blacker Airport' has an elevation of 620 feet.
# The airport 'Robertson Field' has an elevation of 620 feet.
# The airport 'Wenning Landing Area' has an elevation of 620 feet.
# The airport 'Dudley Airport' has an elevation of 619 feet.
# The airport 'Dudley Airport' has an elevation of 619 feet.
# The airport 'Wards Long Acres Airport' has an elevation of 618 feet.
# The airport 'South Fox Island Airport' has an elevation of 616 feet.
# The airport 'Custer Airport' has an elevation of 616 feet.
# The airport 'Gross Airport' has an elevation of 615 feet.
# The airport 'Woodside Airport' has an elevation of 615 feet.
# The airport 'McKipley Airport' has an elevation of 614 feet.
# The airport 'Fairlane Plaza Heliport' has an elevation of 614 feet.
# The airport 'Marine City Airport' has an elevation of 613 feet.
# The airport 'Sanko Landing Strip' has an elevation of 613 feet.
# The airport 'Haydens Field' has an elevation of 612 feet.
# The airport 'Iosco County Airport' has an elevation of 611 feet.
# The airport 'Crystal Airport' has an elevation of 610 feet.
# The airport 'Berz-Macomb Airport' has an elevation of 610 feet.
# The airport 'Consumers Power Company Heliport' has an elevation of 610 feet.
# The airport 'Wickenheiser Airport' has an elevation of 610 feet.
# The airport 'Delta County Airport' has an elevation of 609 feet.
# The airport 'Iosco County Airport' has an elevation of 606 feet.
# The airport 'Dearborn Helistop' has an elevation of 606 feet.
# The airport 'Delta County Airport' has an elevation of 606 feet.
# The airport 'De Witt Property Airport' has an elevation of 605 feet.
# The airport 'Erie Aerodrome' has an elevation of 605 feet.
# The airport 'Grand Haven Memorial Airport' has an elevation of 604 feet.
# The airport 'Grand Haven Memorial Airpark' has an elevation of 604 feet.
# The airport 'Riverview Airport' has an elevation of 603 feet.
# The airport 'Park Township Airport' has an elevation of 603 feet.
# The airport 'Grognet Flying Service Seaplane Base' has an elevation of 603 feet.
# The airport 'Calvin Campbell Municipal Airport' has an elevation of 602 feet.
# The airport 'Park Township Airport' has an elevation of 602 feet.
# The airport 'Saint Joseph Hospital Heliport' has an elevation of 602 feet.
# The airport 'Hyatt Regency Hotel Heliport' has an elevation of 602 feet.
# The airport 'Farver Field' has an elevation of 600 feet.
# The airport 'Harry W Browne Airport' has an elevation of 600 feet.
# The airport 'Weller Airport' has an elevation of 600 feet.
# The airport 'Carls Airport' has an elevation of 598 feet.
# The airport 'Saint Marys Hospital Heliport' has an elevation of 595 feet.
# The airport 'Au Gres Airport' has an elevation of 593 feet.
# The airport 'Long Land Farm Landing Strip' has an elevation of 591 feet.
# The airport 'Grosse Ile Municipal Airport' has an elevation of 591 feet.
# The airport 'Grosse Ile Municipal Airport' has an elevation of 591 feet.
# The airport 'Kenneth Hayward Airport' has an elevation of 590 feet.
# The airport 'Mills Field' has an elevation of 590 feet.
# The airport 'Dow Chemical Heliport' has an elevation of 588 feet.
# The airport 'B C Cobb Heliport' has an elevation of 586 feet.
# The airport 'Baker Airport' has an elevation of 586 feet.
# The airport 'Sebewaing Airport' has an elevation of 585 feet.
# The airport 'Harold Miller Heliport' has an elevation of 585 feet.
# The airport 'James Clements Municipal Airport' has an elevation of 585 feet.
# The airport 'Sebewaing Airport' has an elevation of 584 feet.
# The airport 'James Clements Municipal Airport' has an elevation of 584 feet.
# The airport 'Ashman Island Seaplane Base' has an elevation of 581 feet.
# The airport 'Selfridge ANGB Airport' has an elevation of 580 feet.
# The airport 'Soo Seaplane Base' has an elevation of 580 feet.
# The airport 'Moran Bay Seaplane Base' has an elevation of 580 feet.
# The airport 'Crandell Airport' has an elevation of 579 feet.
# The airport 'General Hospital Heliport' has an elevation of 578 feet.
# The airport 'Mecosta County General Hospital Heliport' has an elevation of 9 feet.
# The airport 'Cheboygan City-County Airport' has an elevation of 0 feet.
# The airport 'Baarlear Landing Strip' has an elevation of 0 feet.
# The airport 'Empire Airport' has an elevation of 0 feet.
# The airport 'City County Airport' has an elevation of 0 feet.
# The airport 'Muskegon County Airport' has an elevation of 0 feet.
# The airport 'Ross Field' has an elevation of 0 feet.
# The airport 'Hickcox Landing Strip' has an elevation of 0 feet.
# The airport 'Sault Sainte Marie Municipal Airport' has an elevation of 0 feet.
# The airport 'Drummond Island Airport' has an elevation of 0 feet.
# The airport 'Bois Blanc Landing Field' has an elevation of 0 feet.

# %%
# Check for the presence of airports in elevation_sorted

if not elevation_sorted: # if len(elevation_sorted) == 0:
    print("No airports found.")
else:
    highest_elevation_airport = elevation_sorted[0]['properties']['NAME']
    highest_elevation = elevation_sorted[0]['properties']['ELEVATION']
    
    print(f"The airport with the highest elevation is {highest_elevation_airport} with an elevation of {highest_elevation} feet.")
# Out:
# The airport with the highest elevation is Marenisco Landing Field with an elevation of 1638 feet.

# %% [markdown]
# ## Opening Landsat imagery with rasterio

# %%
import rasterio

# %%
raster = rasterio.open("LE70220492002106EDC00_stack.gtif")
raster
# Out:
# <open DatasetReader name='LE70220492002106EDC00_stack.gtif' mode='r'>

# %%
# Import the show method to display our raster
from rasterio.plot import show

# %%
# Read Red (band 3) and Near Infrared (band 4) bands
red = raster.read(3)
nir = raster.read(4)

# Calculate NDVI
ndvi = (nir - red) / (nir + red)
ndvi
# Out:
# array([[0.37269557, 0.39126166, 0.44422984, ..., 0.36966394, 0.40647922,
#         0.51700087],
#        [0.3250366 , 0.3498452 , 0.3970338 , ..., 0.38437597, 0.39950526,
#         0.42797119],
#        [0.33222116, 0.3498452 , 0.37306202, ..., 0.37700787, 0.37754792,
#         0.415     ],
#        ...,
#        [0.27515723, 0.27947817, 0.26802586, ..., 0.29664874, 0.32523851,
#         0.34447539],
#        [0.28249027, 0.28341426, 0.27947817, ..., 0.37880738, 0.36796159,
#         0.2972973 ],
#        [0.29672006, 0.30234934, 0.28967643, ..., 0.34625551, 0.31332745,
#         0.27264015]])

# %%
# Display the NDVI raster plot with a colorbar legend
show(ndvi, cmap='Greys')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.imshow(ndvi, cmap='RdYlGn')
plt.colorbar(label='NDVI')
plt.title('Normalized Difference Vegetation Index (NDVI)')
plt.show()
